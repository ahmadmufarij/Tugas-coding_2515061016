# %%
# 1. buat vector x dengan ukuran 3x1
import numpy as np

# %%
x = np.array([12,13,14])
x
# Out:
# array([12, 13, 14])

# %%
# hitung panjang vector x
len(x)
# Out:
# 3

# %%
#tampilkan ukuran vector x
x.shape
# Out:
# (3,)

# %%
# tampilkan tipe data dari vector x
type(x)
# Out:
# numpy.ndarray

# %%
# akses elemen pertama dari vector x
x[0]
# Out:
# np.int64(12)

# %%
# tampilkan tipe data elemen pertama dari vector x
type(x[0])
# Out:
# numpy.int64

# %%
# 2. lakukan transpose pada vector x dan simpan pada variabel x_t
x_t = x.T
x_t
# Out:
# array([12, 13, 14])

# %%
# tampilkan ukuran dari vector x_t
x_t.shape
# Out:
# (3,)

# %%
# lakukan transpose pada vector y dan simpan pada variabel y_t
y = np.array([34,45,56])
y_t = y.T
y_t
# Out:
# array([34, 45, 56])

# %%
# tampilkan ukuran dari vector x_t
x_t.shape
# Out:
# (3,)

# %%
# lakukan soal nomor 2 menggunakan pytorch dan tensorflow
import torch
import tensorflow as tf

# %%
x_pt = torch.tensor([12,13,14])
x_pt
# Out:
# tensor([12, 13, 14])

# %%
x_tf = tf.Variable([12,13,14])
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([12, 13, 14], dtype=int32)>
