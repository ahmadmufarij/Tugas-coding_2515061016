# %% [markdown]
# Matriks Tensor

# %% [markdown]
# 1. buat matrix X berukuran 2x3 menggunakan numpy

# %%
import numpy as np

# %%
x = np.array([[16, 25], [17, 18], [90, 14]])
x
# Out:
# array([[16, 25],
#        [17, 18],
#        [90, 14]])

# %%
# tampilkan ukuran dari matrix X
x.shape
# Out:
# (3, 2)

# %%
# tampilkan seluruh elemen dari kolom pertama dari matrix X
x[:,0]
# Out:
# array([16, 17, 90])

# %%
# tampilkan seluruh elemen dari baris kedua dari matrix X
x[:,1]
# Out:
# array([25, 18, 14])

# %% [markdown]
# NO. 2

# %% [markdown]
# pytorch

# %%
# ulangi soal nomor 1 menggunakan pytorch
import torch

# %%
x_pt = torch.tensor([[16, 25], [17, 18], [90, 14]])
x_pt
# Out:
# tensor([[16, 25],
#         [17, 18],
#         [90, 14]])

# %%
x_pt.shape
# Out:
# torch.Size([3, 2])

# %%
x_pt[0,:]
# Out:
# tensor([16, 25])

# %%
x_pt[1,:]
# Out:
# tensor([17, 18])

# %% [markdown]
# tensorflow

# %%
# ulangi soal nomor 1 menggunakan tensorflow
import tensorflow as tf

# %%
x_tf = tf.Variable([[16, 25], [17, 18], [90, 14]])
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3, 2) dtype=int32, numpy=
# array([[16, 25],
#        [17, 18],
#        [90, 14]], dtype=int32)>

# %%
tf.shape(x_tf)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([3, 2], dtype=int32)>

# %%
x_tf[0,:]
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([16, 25], dtype=int32)>

# %%
x_tf[1,:]
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([17, 18], dtype=int32)>
