# %%
# buat variabel skalar x dan simpan suatu nilai skalar
x = 1016
x
# Out:
# 1016

# %%
# tampilkan tipe data dari x
type (x)
# Out:
# int

# %%
# buat variabel skalar y dan disimpan suatu nilai skalar
y = 1016
y
# Out:
# 1016

# %%
# tampilkan tipe data dari y
type (y)
# Out:
# int

# %%
# jumlahan x + y
py_sum = x + y
py_sum
# Out:
# 2032

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
x_float = 16.0
x_float
# Out:
# 16.0

# %%
# jumlahkan x_float dengan y
py_sum = x_float + y
py_sum
# Out:
# 1032.0

# %%
# tampilkan tipe data dari x_float
type(x_float)
# Out:
# float

# %%
# lakukan tahapan pada soal 1 dengan menggunakan tensorflow
import tensorflow as tf

# %%
x_tf = tf.Variable(1016, dtype=tf.int16)
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int16, numpy=1016>

# %%
x_tf.shape
# Out:
# TensorShape([])

# %%
y_tf = tf.Variable(1016, dtype=tf.int16)

# %%
x_tf + y_tf
# Out:
# <tf.Tensor: shape=(), dtype=int16, numpy=2032>

# %%
tf_sum = tf.add(x_tf, y_tf)
tf_sum
# Out:
# <tf.Tensor: shape=(), dtype=int16, numpy=2032>

# %%
tf_sum.numpy()
# Out:
# np.int16(2032)

# %%
type(tf_sum.numpy())
# Out:
# numpy.int16

# %%
tf_float = tf.Variable(16.0, dtype=tf.float16)
tf_float
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float16, numpy=16.0>
